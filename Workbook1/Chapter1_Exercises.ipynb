# %% [markdown]
# Exercise 1

# %%
Print('Hello world!')
#the "Print" word should be "print"

# %%
print'Hello world!')
#the  first constructor is missing "(" it should be "()"

# %%
print('Hello world!)
#the last  quotation is missing (')

# %%
print('Hello world!'')
#the qoutes is extra

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
#the output is 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)
#the second line of code the "X" should be written in small letter "x"

# %%
# !git config --global user.name =  'Shanty Marie Penales' #your full name
# !git config --global user.email = 'shantymarie.penales1029@gmail.com' #the email address you used in creating your GitHub account
#!git config --global user.password = 'xxx your TOKEN xxx' #password should be the token

# %%
# !git clone https://ShantyMariePenales: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@github.com/ShantyMariePenales/ICT110_CS2A_Penales.git
# Out:
# Cloning into 'ICT110_CS2A_Penales'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 2), reused 10 (delta 1), pack-reused 0
# Receiving objects: 100% (13/13), 26.71 KiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
