# %% [markdown]
# Excercise 1

# %%
if x > 0 :
    print('Above 0')
elif x >  10 :
    print('Above 10')
elif x > 50 :
    print('Above 50')
elif x >  20 :
    print('Above 20')
else :
    print('Something else')

# %% [markdown]
# Exercise 2

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours <= 40:
    pay = hours * rate
else:
    regular_pay = 40 * rate
    overtime_pay = (hours - 40) * (1.5 * rate)
    pay = regular_pay + overtime_pay

print("Pay:", pay)

# %% [markdown]
# Challenge

# %%
score = float(input("Enter score between 0 and 100: "))

if score >= 97:
    grade = 1.0
elif score >= 93:
    grade = 1.25
elif score >= 89:
    grade = 1.5
elif score >= 85:
    grade = 1.75
elif score >= 81:
    grade = 2.0
elif score >= 77:
    grade = 2.25
elif score >= 74:
    grade = 2.5
else:
    grade = 3.0

print("Grade:", grade)

# %%
# !git config --global user.name =  'Shanty Marie Penales' #your full name
# !git config --global user.email = 'shantymarie.penales1029@gmail.com' #the email address you used in creating your GitHub account
# !git config --global user.password = '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' #password should be the token

# %%
# !git clone https://ShantyMariePenales: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@github.com/ShantyMariePenales/ICT110_CS2A_Penales.git
# Out:
# Cloning into 'ICT110_CS2A_Penales'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 21 (delta 7), reused 15 (delta 3), pack-reused 0
# Receiving objects: 100% (21/21), 29.07 KiB | 3.23 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter_3_Exercises.ipynb" "/content/ICT110_CS2A_Penales/Workbook1"
