# %%
# !git config --global user.name =  'ShantyMariePenales' #your full name
# !git config --global user.email = 'shantymarie.penales1029@gmail.com' #the email address you used in creating your GitHub account
#!git config --global user.password = 'xxx your TOKEN xxx' #password should be the token

# %%
# !git clone https://ShantyMariePenales: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@github.com/ShantyMariePenales/ICT110_CS2A_Penales.git
# Out:
# Cloning into 'ICT110_CS2A_Penales'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), 25.00 KiB | 441.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter_1_Exercises.ipynb" "/content/ICT110_CS2A_Penales/Workbook1"

# %%
# !pwd
# Out:
# /content/ICT110_CS2A_Penales

# %%
# %cd /content/ICT110_CS2A_Penales
# Out:
# /content/ICT110_CS2A_Penales

# %%
# %ls
# Out:
# Activity_Penales.ipynb  Chapter_1_Exercises.ipynb  penales_Text.txt  Workbook1

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/ICT110_CS2A_Penales/.git/

# %%
# !git add Workbook1/Chapter_1_Exercises.ipynb
# Out:
# fatal: pathspec 'Workbook1/Chapter_1_Exercises.ipynb' did not match any files
