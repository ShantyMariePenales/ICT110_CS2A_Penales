# %% [markdown]
# Exercise 1

# %%
name = input('Enter your name:')
print ('Hello',name)

# %%
float_hours = float(input('Enter hours:'))
float_rate = float(input('Enter rate:'))
pay = float_hours*float_rate
print("Pay:",pay)

# %% [markdown]
# Exercise 3

# %%
width = 17
height = 12.0

print(width//2,(type(width//2)))
print(width/2.0,(type(width/2.0)))
print(height/3,(type(height/3)))
print(1 + 2 * 5,(type(1 + 2 * 5)))

# %% [markdown]
# Exericse 4

# %%
number = float(input('Enter a number: '))
square = number*number
print("The square of 3 is",square)

# %% [markdown]
# Challenge

# %%
celsius = float(input("Enter Celsius: "))
fahren = (celsius * (9/5)) + 32
print("Celsius: ", fahren)

# %%
# !git config --global user.name =  'Shanty Marie Penales' #your full name
# !git config --global user.email = 'shantymarie.penales1029@gmail.com' #the email address you used in creating your GitHub account
# !git config --global user.password = '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' #password should be the token

# %%
# !git clone https://ShantyMariePenales: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@github.com/ShantyMariePenales/ICT110_CS2A_Penales.git
# Out:
# Cloning into 'ICT110_CS2A_Penales'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 4), reused 13 (delta 2), pack-reused 0
# Receiving objects: 100% (17/17), 27.81 KiB | 632.00 KiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebook/Chapter_2_Exercises.ipynb" "/content/ICT110_CS2A_Penales/Workbook2"
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebook/Chapter_2_Exercises.ipynb': No such file or directory
