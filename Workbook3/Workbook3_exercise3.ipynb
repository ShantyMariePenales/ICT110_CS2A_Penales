# %% [markdown]
# Exercise 3

# %%
grades = [1.0, 1.25, 1.5, 1.75, 2.0, 2.25, 2.5, 3.0]


for index, grade in enumerate(grades):
    print(index, grade)
# Out:
# 0 1.0
# 1 1.25
# 2 1.5
# 3 1.75
# 4 2.0
# 5 2.25
# 6 2.5
# 7 3.0
