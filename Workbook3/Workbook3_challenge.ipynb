# %% [markdown]
# Challenge

# %%
filename = 'mbox-short.txt'
with open(filename, 'r') as file:
    for line in file:
        if line.startswith('From '):
            words = line.split()
            print(words[2])
