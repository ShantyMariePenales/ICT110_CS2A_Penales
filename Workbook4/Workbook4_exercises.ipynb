# %% [markdown]
# Exercises

# %%
"""
my_variable = "Hello, world!"
def add_numbers(a, b):

    return a + b

def subtract_numbers(a, b):

    return a - b
    import mymodule


print(mymodule.__doc__)

print(mymodule.my_variable)

# Use the functions
print(mymodule.add_numbers(29, 10))
print(mymodule.subtract_numbers(29, 10))
