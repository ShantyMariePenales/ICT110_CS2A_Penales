# %% [markdown]
# Exercise 1

# %%
text = 'Business Analytics'

print(text[4])
print(text[2:4])
print(text[:4])
print(text[4:])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti
