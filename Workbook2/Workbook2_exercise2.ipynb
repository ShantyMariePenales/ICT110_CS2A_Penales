# %% [markdown]
# Exercise 2

# %%
phrase = 'One Ring to rule them all'

word1 = phrase[:4]
word2 = phrase[4:8]
word3 = phrase[-3:]
word4 = phrase[-7:-3]
word5 = phrase

print(word1)
print(word2)
print(word3)
print(word4)
print(word5)
# Out:
# One
# Ring
# all
# hem
# One Ring to rule them all
